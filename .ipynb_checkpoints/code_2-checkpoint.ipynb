# %%
import pandas as pd
import numpy as np

# %%
#read the data
data = pd.read_csv("gdp_emissions.csv")

print(data.head())
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Algeria          DZA
#
#                                          Series Name        Series Code  \
# 0  Adjusted net national income per capita (const...  NY.ADJ.NNTY.PC.KD
# 1             CO2 emissions (metric tons per capita)     EN.ATM.CO2E.PC
# 2  Adjusted net national income per capita (const...  NY.ADJ.NNTY.PC.KD
# 3             CO2 emissions (metric tons per capita)     EN.ATM.CO2E.PC
# 4  Adjusted net national income per capita (const...  NY.ADJ.NNTY.PC.KD
#
#         1992 [YR1992]       1993 [YR1993]       1994 [YR1994]  \
# 0                  ..                  ..                  ..
# 1  0.0961965810608727  0.0850871075160703  0.0758064942125158
# 2                  ..                  ..                  ..
# 3   0.774724910911141   0.723790291969695   0.600203707768206
# ...

# %%
cols_to_drop = ['Series Code']
data= data.drop(cols_to_drop,axis=1)

# %%
data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', '1992 [YR1992]',
#        '1993 [YR1993]', '1994 [YR1994]', '1995 [YR1995]', '1996 [YR1996]',
#        '1997 [YR1997]', '1998 [YR1998]', '1999 [YR1999]', '2000 [YR2000]',
#        '2001 [YR2001]', '2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]',
#        '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]',
#        '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]',
#        '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]',
#        '2017 [YR2017]', '2018 [YR2018]'],
#       dtype='object')

# %%
data['Series Name'].unique()
# Out:
# array(['Adjusted net national income per capita (constant 2010 US$)',
#        'CO2 emissions (metric tons per capita)', nan], dtype=object)

# %%
data['GDP'] = data[]

# %%
# Out:
# [1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]

# %%
years = list(range(1992,2019))
temp_data = data.set_index(['Country Name', 'Country Code'])
print(temp_data.head())
temp_data
# Out:
#                                                                  Series Name  \
# Country Name Country Code
# Afghanistan  AFG           Adjusted net national income per capita (const...
#              AFG                      CO2 emissions (metric tons per capita)
# Albania      ALB           Adjusted net national income per capita (const...
#              ALB                      CO2 emissions (metric tons per capita)
# Algeria      DZA           Adjusted net national income per capita (const...
#
#                                 1992 [YR1992]       1993 [YR1993]  \
# Country Name Country Code
# Afghanistan  AFG                           ..                  ..
#              AFG           0.0961965810608727  0.0850871075160703
# Albania      ALB                           ..                  ..
#              ALB            0.774724910911141   0.723790291969695
# Algeria      DZA             1908.69389366519    1729.18649428863
#
# ...

# %%
temp_data.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-00d5501af411> in <module>
# ----> 1 temp_data.columns()
#
# TypeError: 'Index' object is not callable

# %%
temp_data['GDP']=temp_data[temp_data['Series Name']=='Adjusted net national income per capita (constant 2010 US$)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GDP'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data.groupby("countrycode").agg(
    mean=("ind_prod_const", "mean"),
    std_dev=("ind_prod_const", "first"),
    freq=("ind_prod_const", "count"),
).dropna().reset_index().sort_values(by="countrycode")
