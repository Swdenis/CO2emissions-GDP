# %%
import warnings
import numpy as np
warnings.filterwarnings('ignore')
import pandas as pd
from plotnine import *
import statsmodels.api as sm
import statsmodels.formula.api as smf
import os
import sys
from stargazer.stargazer import Stargazer
from IPython.core.display import HTML

# %%
#read the data
data = pd.read_csv("f7664209-d97b-4f9b-a7bd-e1fef352177c_Data.csv")

print(data.head())
# Out:
#    Time Time Code    Country Name Country Code  \
# 0  1992    YR1992     Afghanistan          AFG
# 1  1992    YR1992         Albania          ALB
# 2  1992    YR1992         Algeria          DZA
# 3  1992    YR1992  American Samoa          ASM
# 4  1992    YR1992         Andorra          AND
#
#   GDP per capita, PPP (constant 2017 international $) [NY.GDP.PCAP.PP.KD]  \
# 0                                                 ..
# 1                                   3275.44433583801
# 2                                   8383.77024779121
# 3                                                 ..
# 4                                                 ..
#
#   CO2 emissions (metric tons per capita) [EN.ATM.CO2E.PC]
# 0                                 0.0961965810608727
# 1                                  0.774724910911141
# 2                                   2.96498636282543
# 3                                                 ..
# 4                                   6.91205338948512

# %%
data.columns
# Out:
# Index(['Time', 'Time Code', 'Country Name', 'Country Code',
#        'GDP per capita, PPP (constant 2017 international $) [NY.GDP.PCAP.PP.KD]',
#        'CO2 emissions (metric tons per capita) [EN.ATM.CO2E.PC]'],
#       dtype='object')

# %%
len(data)
# Out:
# 4516

# %%
data.drop(['Time Code','Country Code'],axis=1,inplace=True)

# %%
cols = {'GDP per capita, PPP (constant 2017 international $) [NY.GDP.PCAP.PP.KD]':'gdppc',
          'CO2 emissions (metric tons per capita) [EN.ATM.CO2E.PC]':'co2pc',
        'Country Name':'country',
       'Time':'year'}
data.rename(columns=cols, inplace=True)

# %%
data.columns
# Out:
# Index(['year', 'country', 'gdppc', 'co2pc'], dtype='object')

# %%
data.country=data.country.astype("category")
data.year=data.year.astype("category")

# %%
data.head()
# Out:
#    year         country             gdppc               co2pc
# 0  1992     Afghanistan                ..  0.0961965810608727
# 1  1992         Albania  3275.44433583801   0.774724910911141
# 2  1992         Algeria  8383.77024779121    2.96498636282543
# 3  1992  American Samoa                ..                  ..
# 4  1992         Andorra                ..    6.91205338948512

# %%
data.replace('..',np.NaN,inplace=True)

# %%
data.isnull().sum()
# Out:
# year         3
# country      5
# gdppc      848
# co2pc      848
# dtype: int64

# %%
data.groupby('country').agg(lambda x: x.isnull().sum()).sort_values(['gdppc']+['co2pc'],ascending=False).head(60)
# Out:
#                            year  gdppc  co2pc
# country
# American Samoa                0     27     27
# Channel Islands               0     27     27
# Guam                          0     27     27
# Isle of Man                   0     27     27
# Monaco                        0     27     27
# Northern Mariana Islands      0     27     27
# St. Martin (French part)      0     27     27
# Virgin Islands (U.S.)         0     27     27
# South Sudan                   0     27     22
# Liechtenstein                 0     27     17
# Eritrea                       0     27      4
# Andorra                       0     27      2
# British Virgin Islands        0     27      2
# Cuba                          0     27      2
# Faroe Islands                 0     27      2
# French Polynesia              0     27      2
# Gibraltar                     0     27      2
# Greenland                     0     27      2
# Korea, Dem. People’s Rep.     0     27      2
# New Caledonia                 0     27      2
# Somalia                       0     27      2
# Syrian Arab Republic          0     27      2
# Venezuela, RB                 0     27      2
# Yemen, Rep.                   0     27      2
# Djibouti                      0     21      2
# Turks and Caicos Islands      0     19      2
# Sint Maarten (Dutch part)     0     17     24
# Cayman Islands                0     14      2
# Nauru                         0     12      2
# Afghanistan                   0     10      2
# Sao Tome and Principe         0      9      2
# Curacao                       0      8     22
# Kosovo                        0      8     18
# Timor-Leste                   0      8     12
# Liberia                       0      8      2
# Palau                         0      8      2
# Qatar                         0      8      2
# Libya                         0      7      2
# San Marino                    0      5     27
# Montenegro                    0      5     15
# Serbia                        0      3     16
# Kuwait                        0      3      5
# Croatia                       0      3      2
# Latvia                        0      3      2
# Lithuania                     0      3      2
# Maldives                      0      3      2
# Moldova                       0      3      2
# Bosnia and Herzegovina        0      2      2
# West Bank and Gaza            0      2      2
# Aruba                         0      1      2
# Cambodia                      0      1      2
# Estonia                       0      1      2
# Puerto Rico                   0      0     27
# Sudan                         0      0     22
# France                        0      0      4
# Italy                         0      0      4
# Albania                       0      0      2
# Algeria                       0      0      2
# Angola                        0      0      2
# Antigua and Barbuda           0      0      2

# %%
temp=data.dropna(axis=0,thresh=4)

# %%
temp.isnull().sum()
# Out:
# year       0
# country    0
# gdppc      0
# co2pc      0
# dtype: int64

# %%
temp
# Out:
#       year              country             gdppc              co2pc
# 1     1992              Albania  3275.44433583801  0.774724910911141
# 2     1992              Algeria  8383.77024779121   2.96498636282543
# 5     1992               Angola  5148.25282361678  0.410522931864339
# 6     1992  Antigua and Barbuda  15497.4647441974    4.0952366180143
# 7     1992            Argentina  16209.3230774449   3.61928035773818
# ...    ...                  ...               ...                ...
# 5417  2016              Vanuatu  3061.78723983667  0.527000323357166
# 5419  2016              Vietnam  6767.90249535442   2.05756591685295
# 5421  2016   West Bank and Gaza  6438.93364028868  0.740606555214825
# 5423  2016               Zambia  3467.87515599636  0.314182894901441
# 5424  2016             Zimbabwe  2934.73365001912  0.782776886458609
#
# [4516 rows x 4 columns]

# %%
temp.groupby('country').agg(lambda x: x.isnull().sum()).sort_values(['gdppc']+['co2pc'],ascending=False).head(60)
# Out:
#                           year  gdppc  co2pc
# country
# Afghanistan                  0    0.0    0.0
# Albania                      0    0.0    0.0
# Algeria                      0    0.0    0.0
# Angola                       0    0.0    0.0
# Antigua and Barbuda          0    0.0    0.0
# Argentina                    0    0.0    0.0
# Armenia                      0    0.0    0.0
# Aruba                        0    0.0    0.0
# Australia                    0    0.0    0.0
# Austria                      0    0.0    0.0
# Azerbaijan                   0    0.0    0.0
# Bahamas, The                 0    0.0    0.0
# Bahrain                      0    0.0    0.0
# Bangladesh                   0    0.0    0.0
# Barbados                     0    0.0    0.0
# Belarus                      0    0.0    0.0
# Belgium                      0    0.0    0.0
# Belize                       0    0.0    0.0
# Benin                        0    0.0    0.0
# Bermuda                      0    0.0    0.0
# Bhutan                       0    0.0    0.0
# Bolivia                      0    0.0    0.0
# Bosnia and Herzegovina       0    0.0    0.0
# Botswana                     0    0.0    0.0
# Brazil                       0    0.0    0.0
# Brunei Darussalam            0    0.0    0.0
# Bulgaria                     0    0.0    0.0
# Burkina Faso                 0    0.0    0.0
# Burundi                      0    0.0    0.0
# Cabo Verde                   0    0.0    0.0
# Cambodia                     0    0.0    0.0
# Cameroon                     0    0.0    0.0
# Canada                       0    0.0    0.0
# Cayman Islands               0    0.0    0.0
# Central African Republic     0    0.0    0.0
# Chad                         0    0.0    0.0
# Chile                        0    0.0    0.0
# China                        0    0.0    0.0
# Colombia                     0    0.0    0.0
# Comoros                      0    0.0    0.0
# Congo, Dem. Rep.             0    0.0    0.0
# Congo, Rep.                  0    0.0    0.0
# Costa Rica                   0    0.0    0.0
# Cote d'Ivoire                0    0.0    0.0
# Croatia                      0    0.0    0.0
# Curacao                      0    0.0    0.0
# Cyprus                       0    0.0    0.0
# Czech Republic               0    0.0    0.0
# Denmark                      0    0.0    0.0
# Djibouti                     0    0.0    0.0
# Dominica                     0    0.0    0.0
# Dominican Republic           0    0.0    0.0
# Ecuador                      0    0.0    0.0
# Egypt, Arab Rep.             0    0.0    0.0
# El Salvador                  0    0.0    0.0
# Equatorial Guinea            0    0.0    0.0
# Estonia                      0    0.0    0.0
# Eswatini                     0    0.0    0.0
# Ethiopia                     0    0.0    0.0
# Fiji                         0    0.0    0.0

# %%
temp.head()
# Out:
#    year              country             gdppc              co2pc
# 1  1992              Albania  3275.44433583801  0.774724910911141
# 2  1992              Algeria  8383.77024779121   2.96498636282543
# 5  1992               Angola  5148.25282361678  0.410522931864339
# 6  1992  Antigua and Barbuda  15497.4647441974    4.0952366180143
# 7  1992            Argentina  16209.3230774449   3.61928035773818

# %%
temp.columns
# Out:
# Index(['year', 'country', 'gdppc', 'co2pc'], dtype='object')

# %%
print(type(temp.gdppc[1]))
print(type(temp.co2pc[1]))
# Out:
# <class 'str'>
# <class 'str'>

# %%
temp.gdppc=pd.to_numeric(temp.gdppc)
temp.co2pc=pd.to_numeric(temp.co2pc)
temp.year=pd.to_numeric(temp.year)

# %%
countries_grouped = temp.groupby("country")

# %%
temp["lngdppc"] = countries_grouped["gdppc"].transform(np.log)
temp["lnco2pc"] = countries_grouped["co2pc"].transform(np.log)
temp["d_lngdppc"] = countries_grouped["lngdppc"].transform("diff")
temp["d_lnco2pc"] = countries_grouped["lnco2pc"].transform("diff")

# %%
data = temp

# %%
temp=temp.dropna(axis=0,thresh=7)

# %%
temp.isnull().sum()
# Out:
# year         0
# country      0
# gdppc        0
# co2pc        0
# lngdppc      0
# lnco2pc      0
# d_lngdppc    0
# d_lnco2pc    0
# dtype: int64

# %%
temp.groupby('country').size().sort_values().head(20)
# Out:
# country
# Eritrea                      0
# Somalia                      0
# San Marino                   0
# Faroe Islands                0
# French Polynesia             0
# Puerto Rico                  0
# Gibraltar                    0
# Syrian Arab Republic         0
# Greenland                    0
# Guam                         0
# Northern Mariana Islands     0
# Cuba                         0
# Isle of Man                  0
# South Sudan                  0
# Korea, Dem. People’s Rep.    0
# Channel Islands              0
# St. Martin (French part)     0
# Venezuela, RB                0
# Monaco                       0
# Virgin Islands (U.S.)        0
# dtype: int64

# %%
###Dropping contries wiht poor coverage (<16 observations)
countries_to_drop=['Sao Tome and Principe','Sudan','Timor-Leste','Djibouti','Curacao','Cayman Islands',
                   'Sint Maarten (Dutch part)','Kosovo','Montenegro','Nauru','Serbia',
                   'Afghanistan','Turks and Caicos Islands',]
temp=temp.set_index('country').drop(index=countries_to_drop,axis=0)

# %%
len(countries_to_drop)
# Out:
# 13

# %%
temp.groupby('country').size().sort_values().tail(20)
# Out:
# country
# Eswatini                24
# Ethiopia                24
# Fiji                    24
# Finland                 24
# Gabon                   24
# Gambia, The             24
# Georgia                 24
# Ecuador                 24
# Germany                 24
# Greece                  24
# Grenada                 24
# Guatemala               24
# Guinea                  24
# Guinea-Bissau           24
# Guyana                  24
# Haiti                   24
# Honduras                24
# Hong Kong SAR, China    24
# Ghana                   24
# Zimbabwe                24
# dtype: int64

# %%
temp.reset_index(inplace=True)

# %%
temp.query("year == 2000").head(20)
# Out:
#                   country  year         gdppc      co2pc    lngdppc   lnco2pc  \
# 1194              Albania  2000   5911.956097   0.978175   8.684732 -0.022067
# 1195              Algeria  2000   8710.455991   2.830380   9.072279  1.040411
# 1196               Angola  2000   4727.967467   0.581961   8.461251 -0.541351
# 1197  Antigua and Barbuda  2000  18311.013715   4.534545   9.815258  1.511725
# 1198            Argentina  2000  18625.288101   3.854992   9.832276  1.349369
# 1199              Armenia  2000   4048.257817   1.128918   8.306042  0.121259
# 1200                Aruba  2000  41022.321554  26.194875  10.621872  3.265564
# 1201            Australia  2000  38462.015363  17.200610  10.557426  2.844945
# 1202              Austria  2000  46551.459787   7.771971  10.748314  2.050524
# 1203           Azerbaijan  2000   4063.471641   3.666271   8.309793  1.299175
# 1204         Bahamas, The  2000  40517.363844   6.545336  10.609486  1.878753
# 1205              Bahrain  2000  49406.216692  28.315878  10.807832  3.343423
# 1206           Bangladesh  2000   1937.729314   0.216416   7.569272 -1.530554
# 1207             Barbados  2000  15124.213425   4.240790   9.624052  1.444749
# 1208              Belarus  2000   8053.173638   5.389745   8.993822  1.684498
# 1209              Belgium  2000  43160.691494  11.229668  10.672685  2.418559
# 1210               Belize  2000   6521.380707   1.601342   8.782841  0.470842
# 1211                Benin  2000   2478.216433   0.232861   7.815294 -1.457314
# 1212              Bermuda  2000  83181.526285   8.361991  11.328781  2.123697
# 1213               Bhutan  2000   4061.450922   0.670088   8.309296 -0.400346
#
#       d_lngdppc  d_lnco2pc
# 1194   0.073565   0.018584
# 1195   0.023712  -0.060106
# 1196  -0.002683   0.008418
# 1197   0.042374   0.025673
# 1198  -0.018927  -0.044544
# 1199   0.063635   0.145755
# 1200   0.052854   1.056720
# 1201   0.026655   0.000600
# 1202   0.030795   0.001608
# 1203   0.097045   0.023858
# 1204   0.027181  -0.015352
# 1205   0.008491   0.000254
# 1206   0.032056   0.052565
# 1207   0.039585  -0.013435
# 1208   0.061092  -0.037604
# 1209   0.034068   0.005057
# 1210   0.088141   0.094005
# 1211   0.027086  -0.006637
# 1212   0.080181  -0.001785
# 1213   0.044549   0.005687

# %%
formula="d_lnco2pc ~ d_lngdppc"

###OLS regression 2000
ols_cross_section2000 = smf.ols("d_lnco2pc ~ d_lngdppc + country", temp.query("year == 2000")).fit(cov_type="HC0")

# %%
models = [ols_cross_section2000]
names = ["Cross-section regression 2000"]
stargazer = Stargazer(models)
stargazer.rename_covariates(
    {
        "Intercept": "Constant",
        "d_lngdppc": "GDP per capita log change, cumulative coeff.",
        "d_lnco2pc": "CO2 emissions per capita log change, cumulative coeff."
    }
)

stargazer.covariate_order(
    [
        "d_lngdppc",
        "Intercept"
    ]
)

stargazer.custom_columns(names, [1])
HTML(stargazer.render_html())
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:1832: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 217, but rank is 169
# <table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="1"><em>Dependent variable:d_lnco2pc</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">Cross-section regression 2000</td></tr><tr><td style="text-align:left"></td><td>(1)</td></tr><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">GDP per capita log change, cumulative coeff.</td><td>0.132<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.000)</td></tr><tr><td style="text-align:left">Constant</td><td>0.017<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.000)</td></tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Observations</td><td>175</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>1.000</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>nan</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>inf (df=0)</td></tr><tr><td style="text-align: left">F Statistic</td><td>19501977596558170148628194131968.000<sup>***</sup> (df=174; 0)</td></tr><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td>
#  <td colspan="1" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %% [markdown]
# The per capita CO2 emissions were 0.132 p.p. higher, on average, in 2000 for every 1 p.p. increase in GDP per capita, controlling for a country.

# %%
temp.query("year == 2015")
# Out:
#                   country  year         gdppc     co2pc    lngdppc   lnco2pc  \
# 3861              Albania  2015  11916.422315  1.602648   9.385673  0.471657
# 3862              Algeria  2015  11696.963757  3.854557   9.367085  1.349256
# 3863               Angola  2015   8036.410610  1.240245   8.991738  0.215309
# 3864  Antigua and Barbuda  2015  18595.084904  5.839546   9.830653  1.764653
# 3865            Argentina  2015  23933.886613  4.664011  10.083051  1.539876
# ...                   ...   ...           ...       ...        ...       ...
# 4032              Vanuatu  2015   3037.784742  0.486896   8.018884 -0.719706
# 4033              Vietnam  2015   6438.260271  2.032108   8.770014  0.709073
# 4034   West Bank and Gaza  2015   6048.976597  0.704186   8.707644 -0.350712
# 4035               Zambia  2015   3443.555206  0.285428   8.144260 -1.253766
# 4036             Zimbabwe  2015   2958.209004  0.891624   7.992339 -0.114711
#
#       d_lngdppc  d_lnco2pc
# 3861   0.024857  -0.170233
# 3862   0.015878   0.031293
# 3863  -0.024997  -0.294360
# 3864   0.026751   0.023345
# 3865   0.016165   0.016382
# ...         ...        ...
# 4032  -0.025446  -0.181224
# 4033   0.054217   0.107750
# 4034   0.013633   0.034828
# 4035  -0.001883  -0.024175
# 4036   0.001004  -0.000129
#
# [176 rows x 8 columns]

# %%
formula="d_lnco2pc ~ d_lngdppc"

###Pooled regression 2015
ols_pooled2015 = smf.ols("d_lnco2pc ~ d_lngdppc + country", temp.query("year == 2015")).fit(cov_type="HC0")

# %%
models = [ols_pooled2015]
names = ["Pooled regression 2015"]
stargazer = Stargazer(models)
stargazer.rename_covariates(
    {
        "Intercept": "Constant",
        "d_lngdppc": "GDP per capita log change, cumulative coeff.",
        "d_lnco2pc": "CO2 emissions per capita log change, cumulative coeff."
    }
)

stargazer.covariate_order(
    [
        "d_lngdppc",
        "Intercept"
    ]
)

stargazer.custom_columns(names, [1])
HTML(stargazer.render_html())
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:1832: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 217, but rank is 171
# <table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="1"><em>Dependent variable:d_lnco2pc</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">Pooled regression 2015</td></tr><tr><td style="text-align:left"></td><td>(1)</td></tr><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">GDP per capita log change, cumulative coeff.</td><td>0.149<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.000)</td></tr><tr><td style="text-align:left">Constant</td><td>-0.003<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.000)</td></tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Observations</td><td>176</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>1.000</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>nan</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>inf (df=0)</td></tr><tr><td style="text-align: left">F Statistic</td><td>175152020865787132682754351693824.000<sup>***</sup> (df=175; 0)</td></tr><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td>
#  <td colspan="1" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %% [markdown]
# The per capita CO2 emissions were 0.149 p.p. higher, on average, in 2015 for every 1 p.p. increase in GDP per capita, controlling for a country.

# %%
# Fd, time trend, no lags

model = smf.wls("d_lnco2pc ~ d_lngdppc + year", temp)
fd_lm = model.fit(
    cov_type="cluster",
    cov_kwds={"groups": temp.loc[model.data.row_labels, "country"]},
)
fd_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:              d_lnco2pc   R-squared:                       0.075
# Model:                            WLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     18.55
# Date:                Wed, 31 Mar 2021   Prob (F-statistic):           4.87e-08
# Time:                        14:43:35   Log-Likelihood:                 2858.4
# No. Observations:                4213   AIC:                            -5711.
# Df Residuals:                    4210   BIC:                            -5692.
# Df Model:                           2
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1407      0.489      0.288      0.773      -0.817       1.098
# d_lngdppc      0.6142      0.102      6.046      0.000       0.415       0.813
# year       -7.012e-05      0.000     -0.288      0.774      -0.001       0.000
# ==============================================================================
# Omnibus:                     1844.627   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           166438.455
# Skew:                           1.162   Prob(JB):                         0.00
# Kurtosis:                      33.704   Cond. No.                     5.84e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The condition number is large, 5.84e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# A 1 p.p. increase in GDP per capita tend to be followed by 0.61 p.p. increase in CO2 emissions per capita, on average, in the data, relative to the country trend.

# %%
# FD, time trend, 2 year lags

fd_lm_5_cumul_trend_formula = "d_lnco2pc ~ d_lngdppc.shift(0) + d_lngdppc.shift(1) + \
d_lngdppc.shift(2)+ year"

model = smf.wls(
    fd_lm_5_cumul_trend_formula,
    temp
)

fd_lm_5_cumul_trend = model.fit(
    cov_type="cluster",
    cov_kwds={"groups":  temp.loc[model.data.row_labels, "country"]},
)

fd_lm_5_cumul_trend.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:              d_lnco2pc   R-squared:                       0.075
# Model:                            WLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     9.375
# Date:                Wed, 31 Mar 2021   Prob (F-statistic):           6.77e-07
# Time:                        14:43:35   Log-Likelihood:                 2857.1
# No. Observations:                4211   AIC:                            -5704.
# Df Residuals:                    4206   BIC:                            -5672.
# Df Model:                           4
# Covariance Type:              cluster
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.1525      0.490      0.312      0.755      -0.807       1.112
# d_lngdppc.shift(0)     0.6156      0.102      6.046      0.000       0.416       0.815
# d_lngdppc.shift(1)    -0.0222      0.023     -0.966      0.334      -0.067       0.023
# d_lngdppc.shift(2)     0.0238      0.027      0.879      0.380      -0.029       0.077
# year               -7.603e-05      0.000     -0.311      0.756      -0.001       0.000
# ==============================================================================
# Omnibus:                     1842.843   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           166181.820
# Skew:                           1.161   Prob(JB):                         0.00
# Kurtosis:                      33.688   Cond. No.                     5.85e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The condition number is large, 5.85e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# A 1 p.p. increase in GDP per capita tends to be followed by 0.62 p.p. cumulative increase in CO2 emissions per capita, on average, within two years in the data, relative to the country trend.

# %%
# FD, time trend, 6 year lags

fd_lm_5_cumul_trend_formula = "d_lnco2pc ~ d_lngdppc.shift(0) + d_lngdppc.shift(1) + \
d_lngdppc.shift(2)+d_lngdppc.shift(3)+d_lngdppc.shift(4)+d_lngdppc.shift(5)+d_lngdppc.shift(6)+year"

model = smf.wls(
    fd_lm_5_cumul_trend_formula,
    temp
)

fd_lm_5_cumul_trend = model.fit(
    cov_type="cluster",
    cov_kwds={"groups":  temp.loc[model.data.row_labels, "country"]},
)

fd_lm_5_cumul_trend.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:              d_lnco2pc   R-squared:                       0.076
# Model:                            WLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     4.797
# Date:                Wed, 31 Mar 2021   Prob (F-statistic):           2.35e-05
# Time:                        14:43:35   Log-Likelihood:                 2875.0
# No. Observations:                4207   AIC:                            -5732.
# Df Residuals:                    4198   BIC:                            -5675.
# Df Model:                           8
# Covariance Type:              cluster
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.2176      0.479      0.454      0.650      -0.722       1.157
# d_lngdppc.shift(0)     0.6194      0.103      5.991      0.000       0.417       0.822
# d_lngdppc.shift(1)    -0.0162      0.023     -0.692      0.489      -0.062       0.030
# d_lngdppc.shift(2)     0.0237      0.026      0.910      0.363      -0.027       0.075
# d_lngdppc.shift(3)    -0.0340      0.030     -1.119      0.263      -0.094       0.026
# d_lngdppc.shift(4)    -0.0269      0.025     -1.080      0.280      -0.076       0.022
# d_lngdppc.shift(5)    -0.0080      0.031     -0.261      0.794      -0.068       0.052
# d_lngdppc.shift(6)    -0.0116      0.028     -0.416      0.678      -0.066       0.043
# year                  -0.0001      0.000     -0.450      0.653      -0.001       0.000
# ==============================================================================
# Omnibus:                     1892.331   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           168685.249
# Skew:                           1.224   Prob(JB):                         0.00
# Kurtosis:                      33.924   Cond. No.                     5.85e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The condition number is large, 5.85e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# A 1 p.p. increase in GDP per capita tends to be followed by 0.55 p.p. increase in CO2 emissions per capita, on average, within six years in the data, relative to the country trend.

# %%
###Panel regression
from linearmodels import PanelOLS

# %%
data = data.set_index(['country', 'year'])

# %%
data.tail()
# Out:
#                                gdppc     co2pc   lngdppc   lnco2pc  d_lngdppc  \
# country            year
# Vanuatu            2016  3061.787240  0.527000  8.026754 -0.640554   0.007870
# Vietnam            2016  6767.902495  2.057566  8.819946  0.721524   0.049933
# West Bank and Gaza 2016  6438.933640  0.740607  8.770118 -0.300286   0.062474
# Zambia             2016  3467.875156  0.314183  8.151297 -1.157780   0.007038
# Zimbabwe           2016  2934.733650  0.782777  7.984372 -0.244908  -0.007967
#
#                          d_lnco2pc
# country            year
# Vanuatu            2016   0.079151
# Vietnam            2016   0.012450
# West Bank and Gaza 2016   0.050427
# Zambia             2016   0.095986
# Zimbabwe           2016  -0.130197

# %%
fe = PanelOLS.from_formula(
    "lnco2pc ~ lngdppc + TimeEffects + EntityEffects",
    data
).fit(cov_type="clustered", cluster_entity=True)

# %%
fe.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                lnco2pc   R-squared:                        0.2562
# Estimator:                   PanelOLS   R-squared (Between):             -12.225
# No. Observations:                4516   R-squared (Within):               0.3598
# Date:                Wed, Mar 31 2021   R-squared (Overall):             -12.315
# Time:                        14:43:36   Log-likelihood                    466.52
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1480.9
# Entities:                         217   P-value                           0.0000
# Avg Obs:                       20.811   Distribution:                  F(1,4300)
# Min Obs:                       0.0000
# Max Obs:                       25.000   F-statistic (robust):             22.726
#                                         P-value                           0.0000
# Time periods:                      25   Distribution:                  F(1,4300)
# Avg Obs:                       180.64
# Min Obs:                       164.00
# Max Obs:                       191.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# lngdppc        0.7484     0.1570     4.7672     0.0000      0.4406      1.0562
# ==============================================================================
#
# F-test for Poolability: 178.03
# P-value: 0.0000
# Distribution: F(214,4300)
#
# Included effects: Entity, Time
# """

# %% [markdown]
# Per capita CO2 emissions tend to be 0.75 p.p. higher, on average, for a 1 p.p. increase in per capita GDP within the data, compared to mean per capita CO2 emissions for a country and within a given year.

# %% [markdown]
# The long difference regression

# %%
temp.query("year == 1993 | year == 2016")
# Out:
#                   country  year         gdppc     co2pc   lngdppc   lnco2pc  \
# 0                 Albania  1993   3610.520633  0.723790  8.191607 -0.323254
# 1                 Algeria  1993   8027.376688  2.974812  8.990613  1.090181
# 2                  Angola  1993   3788.508107  0.441721  8.239728 -0.817077
# 3     Antigua and Barbuda  1993  15991.764201  4.125424  9.679829  1.417169
# 4               Argentina  1993  17312.030499  3.471494  9.759157  1.244585
# ...                   ...   ...           ...       ...       ...       ...
# 4208              Vanuatu  2016   3061.787240  0.527000  8.026754 -0.640554
# 4209              Vietnam  2016   6767.902495  2.057566  8.819946  0.721524
# 4210   West Bank and Gaza  2016   6438.933640  0.740607  8.770118 -0.300286
# 4211               Zambia  2016   3467.875156  0.314183  8.151297 -1.157780
# 4212             Zimbabwe  2016   2934.733650  0.782777  7.984372 -0.244908
#
#       d_lngdppc  d_lnco2pc
# 0      0.097398  -0.068006
# 1     -0.043440   0.003309
# 2     -0.306685   0.073247
# 3      0.031397   0.007344
# 4      0.065815  -0.041690
# ...         ...        ...
# 4208   0.007870   0.079151
# 4209   0.049933   0.012450
# 4210   0.062474   0.050427
# 4211   0.007038   0.095986
# 4212  -0.007967  -0.130197
#
# [340 rows x 8 columns]

# %%
# Long difference

model = smf.wls("d_lnco2pc ~ d_lngdppc", temp.query("year == 1993 | year == 2016"))
longd_lm = model.fit(
    cov_type="cluster",
    cov_kwds={"groups": temp.loc[model.data.row_labels, "country"]},
)
longd_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:              d_lnco2pc   R-squared:                       0.115
# Model:                            WLS   Adj. R-squared:                  0.113
# Method:                 Least Squares   F-statistic:                     19.93
# Date:                Wed, 31 Mar 2021   Prob (F-statistic):           1.43e-05
# Time:                        14:48:07   Log-Likelihood:                 283.89
# No. Observations:                 340   AIC:                            -563.8
# Df Residuals:                     338   BIC:                            -556.1
# Df Model:                           1
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0051      0.006      0.845      0.398      -0.007       0.017
# d_lngdppc      0.6812      0.153      4.464      0.000       0.382       0.980
# ==============================================================================
# Omnibus:                      104.034   Durbin-Watson:                   1.977
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2539.289
# Skew:                          -0.636   Prob(JB):                         0.00
# Kurtosis:                      16.328   Cond. No.                         18.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %% [markdown]
# A 1 p.p. increase in GDP per capita tends to be followed by 0.68 p.p. increase in CO2 emissions per capita, on average, between 1993 and 2016 in the data.
